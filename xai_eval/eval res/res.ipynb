# %%
import pandas as pd

# %%
lime_eval = pd.read_csv("xai_lime_eval.csv")
shap_eval = pd.read_csv("xai_shap_eval.csv")
ig_eval = pd.read_csv("xai_ig_eval.csv")

# %%
lime_eval.describe()
# Out:
#          LIME_time  LIME_comp_3  LIME_suff_3  LIME_comp_5  LIME_suff_5  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.576715     0.309039     0.348737     0.395059     0.242348
# std       0.587671     0.389799     0.393143     0.410782     0.370633
# min       0.468815    -0.219984    -0.634131    -0.092438    -0.679291
# 25%       1.135475     0.000371     0.004128     0.002068     0.000726
# 50%       1.532740     0.045704     0.158722     0.203937     0.026346
# 75%       2.078097     0.724750     0.755840     0.870162     0.539697
# max       3.588700     0.999261     0.998627     0.999241     0.998804
#
#        LIME_comp_7  LIME_suff_7  LIME_comp_9  LIME_suff_9
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.440323     0.184015     0.474475     0.143154
# std       0.412873     0.346730     0.412656     0.327730
# min      -0.168093    -0.706076    -0.090108    -0.644491
# ...

# %%
shap_eval.describe()
# Out:
#          SHAP_time  SHAP_comp_3  SHAP_suff_3  SHAP_comp_5  SHAP_suff_5  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.620924     0.213336     0.302697     0.273910     0.178255
# std       0.660191     0.350282     0.385518     0.380727     0.338075
# min       1.496378    -0.379035    -0.665980    -0.381838    -0.620302
# 25%       2.004573     0.000006     0.002095     0.000079     0.000130
# 50%       2.658605     0.003924     0.099258     0.016832     0.008027
# 75%       2.841914     0.329735     0.680193     0.582262     0.309050
# max       6.933517     0.999318     0.996678     0.999273     0.995885
#
#        SHAP_comp_7  SHAP_suff_7  SHAP_comp_9  SHAP_suff_9
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.314886     0.139473     0.346122     0.110025
# std       0.395705     0.312005     0.403455     0.285233
# min      -0.294069    -0.621030    -0.309275    -0.621576
# ...

# %%
ig_eval.describe()
# Out:
#            IG_time    IG_comp_3    IG_suff_3    IG_comp_5    IG_suff_5  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.025592     0.028122     0.733033     0.055559     0.665651
# std       0.202452     0.158547     0.308236     0.202570     0.365040
# min       0.719072    -0.470405    -0.408138    -0.462048    -0.603742
# 25%       0.855638    -0.000457     0.637682    -0.000384     0.445487
# 50%       1.025138     0.000010     0.877207     0.000075     0.844921
# 75%       1.100572     0.002560     0.944322     0.008442     0.947882
# max       1.972605     0.997560     0.999210     0.998143     0.999378
#
#          IG_comp_7    IG_suff_7    IG_comp_9    IG_suff_9
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.081621     0.618709     0.095961     0.563977
# std       0.240016     0.393744     0.261418     0.415581
# min      -0.446758    -0.691714    -0.521951    -0.674402
# ...
